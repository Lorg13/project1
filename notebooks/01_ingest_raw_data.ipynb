# %%
raw_df = spark.read.table("workspace.default.raw_table")

# %%
raw_df.printSchema()
raw_df.limit(5).display()
raw_df.count()

# %%
raw_df.write.mode("overwrite").saveAsTable("workspace.default.raw_table")
