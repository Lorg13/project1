# %%
from pyspark.sql.functions import col, when
from src.zephyr.etl.cleaning import clean_data

df = spark.read.table("workspace.default.raw_table")

# %%
df = clean_data(df)

# %%
df.write.mode("overwrite").saveAsTable("workspace.default.clean_table")
